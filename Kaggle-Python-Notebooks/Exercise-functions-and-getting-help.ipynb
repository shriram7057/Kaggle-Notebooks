# %% [markdown]
# **This notebook is an exercise in the [Python](https://www.kaggle.com/learn/python) course.  You can reference the tutorial at [this link](https://www.kaggle.com/colinmorris/functions-and-getting-help).**
#
# ---

# %% [markdown]
# Functions are powerful. Try writing some yourself.
#
# As before, don't forget to run the setup code below before jumping into question 1.

# %%
# SETUP. You don't need to worry for now about what this code does or how it works.
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex2 import *
print('Setup complete.')
# Out:
# WARNING:root:Ignoring repeated attempt to bind to globals
# Setup complete.

# %% [markdown]
# # 1.
#
# Complete the body of the following function according to its docstring.
#
# HINT: Python has a built-in function `round`.

# %%
from learntools.python.ex3 import *

def round_to_two_places(num):
    return round(num, 2)

# Define a function called sign (NOT a variable)
def sign(x):
    if x > 0:
        return 1
    elif x < 0:
        return -1
    else:
        return 0

q1.check()
# Out:
# Correct

# %%
# Uncomment the following for a hint
q1.hint()
# Or uncomment the following to peek at the solution
q1.solution()
# Out:
# Sorry, no hints available for this question.
# Solution:
# ```python
# def sign(x):
#     if x > 0:
#         return 1
#     elif x < 0:
#         return -1
#     else:
#         return 0
# ```

# %% [markdown]
# # 2.
# The help for `round` says that `ndigits` (the second argument) may be negative.
# What do you think will happen when it is? Try some examples in the following cell.

# %%
# Put your test code here
# Try round with negative ndigits
print(round(1234.56, -1))   # rounds to nearest 10
print(round(1234.56, -2))   # rounds to nearest 100
print(round(1234.56, -3))   # rounds to nearest 1000
print(round(15, -1))        # rounds to nearest 10
# Out:
# 1230.0
# 1200.0
# 1000.0
# 20

# %% [markdown]
# Can you think of a case where this would be useful?  Once you're ready, run the code cell below to see the answer and to receive credit for completing the problem.

# %%
# Check your answer (Run this code cell to receive credit!)
q2.solution()
# Out:
# Solution: As you've seen, `ndigits=-1` rounds to the nearest 10, `ndigits=-2` rounds to the nearest 100 and so on. Where might this be useful? Suppose we're dealing with large numbers:
#
# > The area of Finland is 338,424 km²
# > The area of Greenland is 2,166,086 km²
#
# We probably don't care whether it's really 338,424, or 338,425, or 338,177. All those digits of accuracy are just distracting. We can chop them off by calling `round()` with `ndigits=-3`:
#
# > The area of Finland is 338,000 km²
# > The area of Greenland is 2,166,000 km²
#
# (We'll talk about how we would get the commas later when we talk about string formatting :))

# %% [markdown]
# # 3.
#
# In the previous exercise, the candy-sharing friends Alice, Bob and Carol tried to split candies evenly. For the sake of their friendship, any candies left over would be smashed. For example, if they collectively bring home 91 candies, they'll take 30 each and smash 1.
#
# Below is a simple function that will calculate the number of candies to smash for *any* number of total candies.
#
# Modify it so that it optionally takes a second argument representing the number of friends the candies are being split between. If no second argument is provided, it should assume 3 friends, as before.
#
# Update the docstring to reflect this new behaviour.

# %%
# Candidate inputs to try (uncomment exactly one block at a time,
# run the cell, then run q4.check()).

# Candidate A — edge-case on rain threshold (tests < vs <= bugs)
#have_umbrella = False
#rain_level   = 0.5
#have_hood    = False
#is_workday   = True

# Candidate B — hood present but no umbrella (tests whether hood is treated as protection)
#have_umbrella = False
#rain_level    = 0.8
#have_hood     = True
#is_workday     = True

# Candidate C — heavy rain and no protection (should be NOT prepared)
#have_umbrella = False
#rain_level    = 1.0
#have_hood     = False
#is_workday     = True

# Candidate D — not a workday but moderate rain and hood available (tests is_workday handling)
#have_umbrella = False
#rain_level    = 0.6
#have_hood     = True
#is_workday     = False

# Candidate E — umbrella present but very light rain on a workday (tests odd precedence bugs)
#have_umbrella = True
#rain_level    = 0.1
#have_hood     = False
#is_workday     = True

# Candidate F — another edge case: rain exactly zero but no protection
#have_umbrella = False
#rain_level    = 0.0
#have_hood     = False
#is_workday     = True

# --- Default: try Candidate B first (uncomment one of the candidate blocks above to switch) ---
have_umbrella = False
rain_level    = 0.8
have_hood     = True
is_workday     = True

# Print what we're testing (helps debugging)
print("have_umbrella =", have_umbrella)
print("rain_level    =", rain_level)
print("have_hood     =", have_hood)
print("is_workday     =", is_workday)

# If you want to see what prepared_for_weather returns (optional),
# uncomment the next line (it may be defined in the notebook already):
# print("prepared_for_weather ->", prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday))

# Now run the grader:
q4.check()
# Out:
# have_umbrella = False
# rain_level    = 0.8
# have_hood     = True
# is_workday     = True
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. Remember, you must create the following variable: `concise_is_negative`

# %%
def to_smash(total_candies):
    """Return the number of leftover candies that must be smashed after distributing
    the given number of candies evenly between 3 friends.
    
    >>> to_smash(91)
    1
    """
    return total_candies % 3

# %%
def to_smash(total_candies, n_friends=3):
    """Return the number of leftover candies after distributing
    evenly among n_friends (default is 3)."""
    return total_candies % n_friends

# %% [markdown]
# # 4. (Optional)
#
# It may not be fun, but reading and understanding error messages will be an important part of your Python career.
#
# Each code cell below contains some commented buggy code. For each cell...
#
# 1. Read the code and predict what you think will happen when it's run.
# 2. Then uncomment the code and run it to see what happens. (**Tip**: In the kernel editor, you can highlight several lines and press `ctrl`+`/` to toggle commenting.)
# 3. Fix the code (so that it accomplishes its intended purpose without throwing an exception)
#
# <!-- TODO: should this be autochecked? Delta is probably pretty small. -->

# %%
# ruound_to_two_places(9.9999)

# %%
# x = -10
# y = 5
# # Which of the two variables above has the smallest absolute value?
# smallest_abs = min(abs(x, y))

# %%
# def f(x):
#     y = abs(x)
# return y

# print(f(5))

# %% [markdown]
# # Keep Going
#
# Nice job with the code. Next up, you'll learn about *conditionals*, which you'll need to **[write interesting programs](https://www.kaggle.com/colinmorris/booleans-and-conditionals)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/python/discussion) to chat with other learners.*
