# %% [markdown]
# # Colab Coder Test Notebook
#
# This notebook is created to unlock the Kaggle **Colab Coder** badge.

# %%
print("Hello from Google Colab!")
# Out:
# Hello from Google Colab!

# %%
import numpy as np

data = np.array([10, 20, 30, 40, 50])
print("Data:", data)
print("Mean:", data.mean())
# Out:
# Data: [10 20 30 40 50]
# Mean: 30.0
